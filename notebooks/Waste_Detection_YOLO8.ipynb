# %%
import streamlit as st
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolov8n.pt")

# Train the model
train_results = model.train(
    data="./Data/GARBAGE CLASSIFICATION 3.v2-gc1.yolov8/data.yaml",  # path to dataset YAML
    epochs=100,  # number of training epochs
    imgsz=640,  # training image size
    device="mps",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.234 🚀 Python-3.11.3 torch-2.9.1 MPS (Apple M4)
# ...

# %%
model = YOLO("runs/detect/train6/weights/last.pt")
model.train(resume=True, device="cpu")
# Out:
# New https://pypi.org/project/ultralytics/8.3.236 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.234 🚀 Python-3.11.3 torch-2.9.1 CPU (Apple M4)
# ...

# %%
# Export the model to ONNX format
path = model.export(format="onnx")  # return path to exported model

model.save("models/yolo8n_waste.pt")
# Out:
# Ultralytics 8.3.234 🚀 Python-3.11.3 torch-2.9.1 CPU (Apple M4)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/Users/sung-hackhong/Ai_Enginiering/git_repos/Capstone_1_Ai_Waste_Detection/runs/detect/train6/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.78...
# ONNX: export success ✅ 0.9s, saved as '/Users/sung-hackhong/Ai_Enginiering/git_repos/Capstone_1_Ai_Waste_Detection/runs/detect/train6/weights/best.onnx' (11.7 MB)
#
# Export complete (1.1s)
# Results saved to /Users/sung-hackhong/Ai_Enginiering/git_repos/Capstone_1_Ai_Waste_Detection/runs/detect/train6/weights
# Predict:         yolo predict task=detect model=/Users/sung-hackhong/Ai_Enginiering/git_repos/Capstone_1_Ai_Waste_Detection/runs/detect/train6/weights/best.onnx imgsz=640
# ...
